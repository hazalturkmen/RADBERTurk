# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile

df = pd.read_excel('/content/drive/MyDrive/Merged_10001_45000- BKatuk_Ozbek 20190915.xlsx')

# %%
df = pd.DataFrame(df, columns= ['Rapor(Sonuc)','Sonuc(Unique)'])

# %%
df
# Out:
#                                             Rapor(Sonuc) Sonuc(Unique)
# 0      SONUç \f3\fs20 [Takipte benzer sulkal SAK bulg...           VAR
# 1      SONUç \lang1053\f0\fs18 [  \lang1055\f2 Akuadu...     SERI DISI
# 2      SONUç \lang1053\f0\fs18 [  \lang1055\f3\fs20 S...           VAR
# 3      SONUç \lang1053\f0\fs18 [ \lang1055\f3 Sol tem...     SERI DISI
# 4      SONUç \lang1053\f0\fs18 \cf1\lang1055\f2 [VP Ş...     SERI DISI
# ...                                                  ...           ...
# 35299  SONUÇ:Normal sınırlarda Pre-kontrast Kranial B...           YOK
# 35300  SONUÇ:Normal sınırlarda Pre-kontrast Kranial B...           YOK
# 35301  SONUç:Normal sınırlarda Pre-kontrast Kranial B...           YOK
# 35302  SONUÇ:Normal sınırlarda Pre-kontrast Kranial B...           YOK
# 35303  SONUÇ:Normal sınırlarda Pre-kontrast Kranial B...           YOK
#
# [35304 rows x 2 columns]

# %%
df=df.drop_duplicates()

# %%
df['Rapor(Sonuc)'] = df['Rapor(Sonuc)'].str[5:]

# %%
kodlar=['\\b KRANİAL BOYUN BT ANJİOGRAFİ TETKİKİ:\\b0','\\lang1055\\f1','\\lang1031\\f2','\\lang1055\\f2','\\lang1053\\f0'
,'\\lang1053\\f1','d\\f0\\fs20','\\f2\\fs22','d\\lang1055\\f2\\fs22','\\lang2057\\f0\\fs18',' \\b KRANİAL BT ANJİOGRAFİ TETKİKİ\\b0'
,'\\f3\\fs20','\lang1055\f3\fs20','\\fs18','\lang1053\f3\fs18','\lang1031','d\lang1055\fs22',' \\f1\\fs22','\lang1055','\fs22','d\qj\lang1031','\lang1055\f0'
,'\b PRE-KONTRAST KRANİAL BT İNCELEMESİ\b0','\\f3\\fs20','\\fs22','\\lang1053\\f2','\\lang1053\\f3','\\fs22','\\f0\\fs22','\\f1\\fs20','\\fs20','d\\qj \\b KRANİAL BT ANJİOGRAFİ TETKİKİ\\b0','\\b SERVİKAL VERTEBRA BT ve 3 BOYUTLU BT TETKİKİ\\b0'
,'\\b KRANİAL  BOYUN BT ANJİOGRAFİ TETKİKİ\\b0','\\b KRANİAL BOYUN BT ANJİOGRAFİ TETKİKİ\\b0','\\b BOYUN KRANİAL BT ANJİOGRAFİ TETKİKİ\\b0 ','\\b PREKONTRAST KRANİAL BT İNCELEMESİ\\b0','\\b KRANİAL BOYUN  BT ANJİOGRAFİ TETKİKİ\\b0','\\f3','\\f2','\\b   SERVİKAL VERTEBRA BT ve 3 BOYUTLU BT TETKİKİ \\b0','\\lang1053\\f4 d\\tx360\\tx720\\tx1080\\tx1440\\tx1800\\tx2160\\tx2520\\tx2880\\tx3240\\tx3600\\tx3960\\tx4320\\tx4680\\tx5040\\tx5400\\tx5760\\tx6120\\tx6480\\tx6840\\tx7200\\tx7560\\tx7920\\tx8280\\tx8640\\tx9000\\tx9360\\tx9720\\tx10080\\tx10440\\tx10800\\tx11160\\tx11520']

# %%
radlex = ['RID11163',
 'RID11296',
 'RID11334',
 'RID11423',
 'RID13173',
 'RID3321',
 'RID35365',
 'RID3663',
 'RID36936',
 'RID3827',
 'RID3864',
 'RID3874',
 'RID3891',
 'RID3899',
 'RID39076',
 'RID3936',
 'RID4002',
 'RID4088',
 'RID4591',
 'RID4650',
 'RID4651',
 'RID4652',
 'RID4653',
 'RID4654',
 'RID4655',
 'RID4700',
 'RID4706',
 'RID4708',
 'RID4710',
 'RID4800',
 'RID4885',
 'RID49953',
 'RID5150',
 'RID5178',
 'RID5425',
 'RID5631',
 'RID6264',
 'RID6527',
 'RID7109',
 'RID9470',
 'RID9814']

# %%
df['Rapor(Sonuc)'] = df['Rapor(Sonuc)'].str.split('Saygılarımla').str[0]
df['Rapor(Sonuc)'] = df['Rapor(Sonuc)'].str.replace('  d ','')
df['Rapor(Sonuc)'] = df['Rapor(Sonuc)'].str.replace('--','')
df['Rapor(Sonuc)'] = df['Rapor(Sonuc)'].str.replace('-','')
df['Rapor(Sonuc)'] = df['Rapor(Sonuc)'].str.replace(':','')
df['Rapor(Sonuc)'] = df['Rapor(Sonuc)'].str.replace('[','')
df['Rapor(Sonuc)'] = df['Rapor(Sonuc)'].str.replace(']','')
df['Rapor(Sonuc)'] = df['Rapor(Sonuc)'].str.replace('{','')
df['Rapor(Sonuc)'] = df['Rapor(Sonuc)'].str.replace('}','')
df['Rapor(Sonuc)'] = df['Rapor(Sonuc)'].str.replace('?','')

# %%
df_list = df["Rapor(Sonuc)"].tolist()

# %%
radlex=set(radlex)

# %%
import re
for r in radlex:
  for s in range(0,len(df_list)):
    df_list[s] = str(df_list[s]).replace(r,'')
    df_list[s] = df_list[s].replace('()','')
    df_list[s] = df_list[s].replace('(,)','')
    df_list[s] = df_list[s].replace(r,'')
    

    for l in kodlar:
       df_list[s] = df_list[s].replace(l,'')

# %%
df_list
# Out:
# [' f3fs20 Takipte benzer sulkal SAK bulguları izlenmiştir.  b KRANİAL BT ANJİOGRAFİ TETKİKİb0  BT ANJİOGRAFİ tetkikinde kaynak imajlardan, vasküler yapıların özellikle ANEVRIZMA, stenoz ve malformasyon yönünden multiplanar ve volumetrik değerlendirilmesine olanak sağlayan MIP, MPR, SSD ve VR algoritmaları kullanılarak 3 boyutlu postproses BT ANJİOGRAFİ görüntüleri oluşturulmuştur. IV yoldan 100 cc non iyonik iyotlu kontrast madde verilmiştir.   Elde olunan 3 Boyutlu BT ANJİOGRAFİ görüntülerinde; her iki ICA orifis kavarnöz supraklinoid segmentlerinde lümende anlamlı darlık oluşturmayan kalsifik plaklar mevcuttur. ASA, ASM ve PSArquote lar normal dolum göstermektedir. Intrakranial arterial yapılarda stenoz, ANEVRIZMAtik dilatasyon ya da vasküler malformasyon bulgusu saptanmamıştır.  f1fs24 SONUç f3fs20 Her iki ICA orifis kavarnöz supraklinoid segmentlerinde lümende anlamlı darlık oluşturmayan kalsifik plaklar mevcuttur.  dlang1031  lang1055f2fs18   lang1053f0 ',
#  ' lang1053f0fs18   lang1055f2 Akuaduktus stenozunu düşündüren her iki lateral ventrikül ve 3. ventriküllerde hidrosefalik dilatasyon, VP ŞANTlang1053f0   ',
#  ' lang1053f0fs18   lang1055f3fs20 Sol anterior talamus bölgesinde milimetrik iskemik enfarkt sekeli ile uyumlu olduğu düşünülen hipodens lezyon izlenmiştir.  İntrakranial kanama izlenmedi. KRANİAL BOYUN  BT ANJİOGRAFİ TETKİKİb0  BT ANJİOGRAFİ tetkikinde kaynak imajlardan, vasküler yapıların özellikle ANEVRIZMA, stenoz ve malformasyon yönünden multiplanar ve volumetrik değerlendirilmesine olanak sağlayan MIP, MPR, SSD ve VR algoritmaları kullanılarak 3 boyutlu postproses BT ANJİOGRAFİ görüntüleri oluşturulmuştur. IV yoldan 100 cc non iyonik iyotlu kontrast madde verilmiştir.   Elde olunan 3 Boyutlu BT ANJİOGRAFİ görüntülerinde; her iki vertebral arter ve baziler arter normal görünümdedir. Her iki ICA kavarnöz ve supraklinoid segmentlerinde lümende anlamlı darlık oluşturmayan kalsifik plaklar izlenmiştir.  ASA, ASM ve PSArquote lar normal dolum göstermektedir. Intrakranial arterial yapılarda stenoz, ANEVRIZMAtik dilatasyon ya da vasküler malformasyon bulgusu saptanmamıştır. Her iki ICA kavarnöz ve supraklinoid segmentlerinde lümende anlamlı darlık oluşturmayan kalsifik plaklar izlenmiştir.  dlang1031  lang1053f0fs18 ',
#  ' lang1053f0fs18  lang1055f3 Sol temporal lob anteriorda önceden geÇirilmiş bir iskemik sürece ait olabilecek fakat eski tetkikleri arşivimizde bulunmadığı iÇin karşılaştırmalı bakı yapılamayan hipodens alan izlenmiştir. Sol MCA bifurkasyon düzeyinde yerleştirildiği tahmin edilen ANEVRIZMA tamirine sekonder METALik klips materyalleri izlenmiştir. Sol parietal ve temporal kemiklerde kraniotomi DEFEKTi ve bu DEFEKT altındaki durada reaktif kalınlaşma ve iÇerisinde milimetrik lipom izlenmiştir. İntra kranial kanama izlenmedi.lang1053f0  ',
#  ' lang1053f0fs18 cf1lang1055f2 VP ŞANTlı olguda güncel tetkikte ventriküllerde hidrosefali aÇısından anlamlı dilatasyon ayırt edilmemiştir.cf0lang1053f0 ',
#  ' lang1053f0fs18 lang1055f1fs20 Perimezensefalik alanda baziler arter tepe kısmında uyan bölgede ANEVRIZMA embolizasyonuna ait koil materyali izlenmiş olup tetkik bu bölgede ARTEFAKTlı değerlendirilmiştir. Raporda belirtilen alanlarda sekel ansefalomalezi alanları mevcut olup her iki lateral ventrikül ve 3. ventrikülde dilatasyon izlenmiştir. 4. ventirkül olağan görünümdedir. Karşılaştırmalı bakıda önceki prekontrast kranial BT tetkiki ile bulgular benzer görünümde izlenmiştir.lang1053f0fs18 ',
#  ' lang1053f0fs18 lang1055f2 f3fs20  sağ serebral konveksitede ARTEFAKT kanama ayrımı net olarak yapılamayan hiperdens milimetrik bir alan izlenmiştir. Kontrol BT ile değerlendirilmesi ÖNERİLİR. Fraktür izlenmedi.  lang1053f0fs18 ',
#  ' lang1053f0fs18 lang1055f3fs20 Belirgin hareket ARTEFAKTlı tetkikte alt bölgeye ait kesitler tanısal değildir. Gereklilik halinde kontrol BT ile değerlendirilmesi ÖNERİLİR. İncelemeye giren kesitlerde akut intra kranial kanama veya akut iskemik enfarkt ile uyumlu alan izlenmemiştir.lang1053f0fs18 ',
#  ' lang1053f0fs18 lang1055f3fs20 Sağ temporal ve perietal kemikte birkaÇ adet DEFEKTi izlenmiştir. Ayrıca parietalde ilerletilip sağ lateral ventrikül posterior hornunda sonlanan VP ŞANT kateteri mevcuttur. Sağ lateral ventrikül posterior  temporal hornunda karşı taraflı kıyaslamalı bakıda dilatasyon bulguları dikkati Çekmiştir. İntrakranial kanama veya ventriküler sistemde hidrosefalik dilatasyon izlenmedi.lang1053f0fs18 ',
#  ' lang1053f0fs18 lang1055f3fs20 Ventriküler sistemde kominikan tipte hidrosefalik dilatasyon izlenmiştir. VP ŞANTlı olgu. Orta hat yapılarında şift veya intra kranial kanama izlenmedi.lang1053f0fs18 ',
#  ' lang1053f0fs18 dqjlang1055f2fs20 Sol bazal ganglioninternal kapsül posterior bacağı düzeyinde  intra parankimal hematom izlenmiştir. Orta hat yapılarında şift izlenmemiştir.Arkus aorta ve arkus aortadan Çıkan ana vasküler yapıların orifislerinde ve sol ICA bifurkasyon düzeyi orifisinde lümenlerde anlamlı darlık oluşturmayan kalsifik aterosklerotik plaklar izlenmiştir. İntra kranial arteriyel yapıların değerlendirilmesi hareket ARTEFAKTları nedeni ile SUBOPTIMAL olmakla beraber anlamlı patolojik bulgu izlenmemiştir. lang1053f0fs18   ',
#  " lang1053f2fs18  Sağ serebral hemisfer temporal lob posteriorunda 2cm boyutta hematom ve Çevresinde vazojenik ödem alanı izlenmektedir.fs18   Sağ temporal lob posteriorda hematom düzeyi komşuluğunda posterior tarafta vaskülaritede artış ve 2mm boyutta psödoANEVRIZMA izlenmektedir. Olası bir AVM aÇısından kuşkulu olup olgunun kanama duyarlı sekanslar eklenerek MR ANJİOGRAFİ tetkiki ile değerlendirmesi ÖNERİLİR.fs18    lang1055f1PARANKİMAL HEMATOM, PS'd6DOANEVRIZMA, MİKRO AVM.  b ",
#  ' lang1053f3fs18   Sol İCA kavernöz segmentte yaklaşık % 50 darlık oluşturan miks tipte aterom plağı izlenmiş olup bunun haricinde her iki İCA da ve arkus aorta  mediastinal ana vasküler yapılar proksimal kesimlerinde anlamlı darlık oluşturmayan kalsifik plaklar izlenmektedir. Total bir oklüzyon veya belirgin bir ANEVRIZMAtik dilatasyon saptanmamıştır.lang1053f3fs18 ',
#  ' lang1053f3fs18  lang1055f0 Sol talamusta intra parankimal hematom ve sol lateral ventrikül ve 3. ventrikül iÇerisinde intra ventriküler hemoraji alıanları izlenmiştir.lang1053f3   lang1055f1fs20 Normal sınırlarda kranial ve boyun  BT ANJİOGRAFİ tetkikilang1053f3fs18   ',
#  '. Olgunun arşivimizde bulunan 30 Mayıs 2019 tarihli(17.40) kontrastsız Kranial BT si ile karışlaştırmalı olarak değerlendirilmiştir. Bulgular bir önceki inceleme ile benzerdir. Bir önceki incelemede ARTEFAKT ile net ayrımı yapılamayan sağ frontal alandaki hiperdens görünümün ARTEFAKT lehine olduğu bu incelemede görülmüştür. İntra kranial kanama saptanmadı. Orta hatta şift saptanmadı.  ',
#  '. VP ŞANT kateteri izlenmiştir. Diğer bulgular benzerdir. lang1053f0 ',
#  "   'd6nceki tetkikte belirtilen sağ frontal ve sağ temporaldeki hiperdens kuşkulu alanlar güncel tetkikte izlenmemiş olup bulgular önceklikle ARTEFAKT lehine değerlendirilmiştir. Yeni gelişen radyopatolojik bulgu saptanmamıştır.  lang1031 dlang1055f2fs20 lang1053f0  ",
#  '   f1fs20 Tetkik yoğun hareket ARTEFAKTı iÇeriyor olup incelemenin tanısal kalitesi oldukÇa düşüktür.f2fs22 Nazal kemik sol yarısında lineer fraktür hattı izlenmiştir. Komşu cilt altı dokuda post travmatik değişiklikler izlenmiştir. Nazal pasaj iÇerisinde hemorajik ürünler izlenmiştir. Normal sınırlarda Prekontrast Kranial BT tetkiki.Yoğun hareket ARTEFAKTı nedeniyle oldukÇa SUBOPTIMAL olan tetkik koşullarında intra kranial kanama ayırtedilmemiştir.  Servikal vertebralarda akut fraktür hattı , dislokasyon saptanmamıştır.  lang1031 20 ',
#  '   lang1055fs22 Belirgin hareket ARTEFAKTlı tetkikte değerlendirme SUBOPTIMAL olmuştur. İntrakranial kanama, fraktür izlenmedi. Servikal vertebralarda aşikar fraktür hattı izlenmemiştirlang1031fs20 .  dlang1055f1  lang1053f0  ',
#  '   lang1055fs22 sağ frontalde konveksiteye yakın düzeyde hemorajik kontüzyon ve beam hardening ARTEFAKTı arasında ayrım yapılamayan hiperdens görünüm izlenmiş olup olgunun takibi ÖNERİLİR.Frontal bölge cilt altında posttravmatik değişiklikler izlenmiştir. Servikal vertebralarda fraktür izlenmedilang1031fs20 .  dlang1053f0  ',
#  '   04.01.2019 tarihli prekontrast kranial BT tetkiki ile benzer görünümde hidrosefali bulguları. VP ŞANTlı hasta.  df0fs20   ',
#  '   Arkus aorta, her iki ICA bifürkasyon düzeyinde ve her iki ICA kavernöz ve supra klinoid segmentlerinde lümende anlamlı darlık oluşturmayan kalsifik plaklar izlenmiştir.  ANEVRIZMAtik dilatasyon veya oklüzyon bulgusu izlenmedi.  lang1031 ',
#  '   Belirgin hareket ARTEFAKTı yüzünden özellikle verteks düzeyine yakın kesitlerde inceleme SUBOPTIMALdir. İntra kranial kanama, kontrastsız BT limitleri dahilinde akut iskemi ile uyumlu alan saptanmadı.  20 ',
#  '   BT limitasyonunda akut iskemi ile uyumlu alan izlenmedi. Sağ ICA bulber segmentinde lümende anlamlı darlık yaratmayan miks tipte ateron plakları izlenmiştir(%3040 darlık). Diğer arteriyel yapılarda stenoz , ANEVRIZMAtik dilatasyon yada vasküler malformasyon bulgusu saptanmadı. lang1053f0fs20 ',
#  '   BT limitasyonunda akut iskemi ile uyumlu alan izlenmedi. Sağ ICA bulber segmentinde lümende anlamlı darlık yaratmayan miks tipte ateron plakları izlenmiştir(%3040 darlık). Diğer arteriyel yapılarda stenoz , ANEVRIZMAtik dilatasyon yada vasküler malformasyon bulgusu saptanmadı. lang1053f0fs20 ',
#  '   BT limitlerinde akut iskemi intrakranial hemoraji izlenmemiştir. Akut iskemi yönünden klinik kuşku varsa olgunun diffüzyon MRG incelemesi ÖNERİLİR. BT ANJİOGRAFİ kesitlerinde arterial yapılar aÇık olup anlamlı darlık ya da oklüzyon bulgusu izlenmemiştir.  df1fs20 lang1053f0  ',
#  "   Frontal kemik üzerinde multıple nondeplase fraktürler izlenmiştir. Frontal sinüs iÇ tabulasında deplase bir fraktür hattı izlenmiştir. Frontal sinüs iÇerisinde hemosinüs ile uyumlu görünüm vardır. Frontal konveksitede yaygın milimetrik pnömosefali alanları ve vertekse yakın düzeyde sağ frontalde yaklaşık 7 mm'lik bir pnömosefali alanı izlenmiştir. Nazal kemikte, nazal septumda ve arkadan vomere kadar uzanan deplase ve fragmante fraktür hatları izlenmiştir. Etmoid hücrelerin duvarlarında multıple deplase fraktürler izlenmiştir. Etmoid hücreler iÇerisinde hemosinüs ile uyumlu görünüm vardır. Bilateral orbita tavanında deplase ve fragmante fraktürler izlenmiştir. Kemik fragmanları beyin parankimine doğru yer değiştirmiştir. Sağ orbita lateral duvarında lineer nondeplase bir fraktür hattı izlenmiştir.   Bilateral maksiller sinüslerin tüm duvarlarında fraktür hattı izlenmiştir. Bilateral maksiller sinüsler iÇerisinde hemosinüs ile uyumlu görünüm vardır.  Hareket ARTEFAKTlı tetkikte seÇilebildiği kadarı ile bilateral pteregoid proceslerde fraktür yönünden kuşkulu hipodens hatlar mevcuttur. Sol temporal kemik skuamöz procesinde lineer nondeplase bir fraktür hattı izlenmiştir. İlgili fraktür hattı sol orbita medial duvarından başlamaktadır. Sağ preseptal bölgede cilt altı hematom ve posttravmatik hava dansiteleri izlenmiştir. Nazal dorsum frontal bölge cilt altında da hematom izlenmiştir. Her iki bulbus oküli izlenebildiği kadarı ile forme görünümdedir. Bilateral orbita ekstrakonal planlarında milimetrik hava dansiteleri izlenmiştir. Falks serebri orta kesimde milimetrik dens bir kalınlaşma izlenmiş olup hastanın takibi ÖNERİLİR.   lang1031bfs20 b0   Servikal vertebralara yönelik ince kesit aksiyel görüntüler elde olunmuştur.  Fraktür/dislokasyon varlığının araştırılması veya konfirme edilmesi iÇin MPR, MIP ve SSD gibi 3 boyutlu BT algoritmaları ile tüm planlarda 3 boyutlu postproses görüntüler oluşturulmuştur.  Tüm servikal vertebra korpus yükseklik ve disk aralıkları normaldir.   Kaynak görüntüler ya da 3 boyutlu BT görüntülerinde fraktür ya da dislokasyon izlenmedi. Spinal kanal Çapı olağandır.   Paravertebral yumuşak dokular normaldir.   Servikal lordoz düzleşmiştir. Servikal lordoz düzleşmiştir. Servikal vertebralarda akut fraktür hattı saptanmadı.  dlang1055f2  lang1053f1  lang2057f0fs18  ",
#  '   Hareket ARTEFAKTlı tetkikte intrakranial kanama izlenmemiştir. Nazal kemik ve nazal septumda minimal deplase fraktür izlenmiştir. Servikal vertebralarda akut fraktür hattı izlenmedi.  df0fs20   ',
#  '   Her iki frontal kemik iÇerisinden geÇerek mezensefalon düzeyinde sonlanan derin beyin stimülatörü kateterleri izlenmiştir. Yerleştirilen materyala bağlı olarak tetkik bu bölgede ARTEFAKTlı görülmüştür. Posterior vertekste 1 cm boyutunda trikilemmal kist izlenmiştir. Akut radyopatolojik bulgu izlenmemiştir.  20 ',
#  '   Hidrosefali . VP ŞANTlı hasta. lang1031 20 ',
#  '   Hidrosefali. VP ŞANT.  ',
#  '   İntra kranial arteriyel yapılarda stenoz, ANEVRIZMAtik dilatasyon veya vasküler malformasyon bulgusu izlenmemiştir. 20 ',
#  '   İntrakranial kanama veya BT limitasyonu dahilinde akut iskemi ile uyumlu alan saptanmamıştır. Klinik gereklilik halinde hastanın kranial BT ANJİOGRAFİ ve difüzyon MRG tetkikleri ile değerlendirilmesi ÖNERİLİR. 20 ',
#  '   Kemik yapılarda multıple sayıda metastatik sklerotik lezyonlar izlenmiştir. İnfratentorial kesitlerin değerlendirilmesinde; beyin sapı, serebellum ve 4. ventrikül olağan izlenmektedir.  Supratentorial kesitlerin değerlendirilmesinde; ventriküler sistemde ve sulkuslarda kortikal atrofiye sekonder ılımlı dilatasyon izlenmiştir. Bunun dışında serebral parankim normal dansitededir. Orta hat yapılarında şift saptanmamıştır.  Hipo ya da hiperdens sınırlanabilen lezyon saptanmamıştır.   Kemik yapılarda multıple sayıda sklerotik metastastik lezyonlar izlenmiştir. BT ANJİOGRAFİ tetkikinde kaynak imajlardan, vasküler yapıların özellikle ANEVRIZMA, stenoz ve malformasyon yönünden multiplanar ve volumetrik değerlendirilmesine olanak sağlayan MIP, MPR, SSD ve VR algoritmaları kullanılarak 3 boyutlu postproses BT ANJİOGRAFİ görüntüleri oluşturulmuştur. IV yoldan 100 cc non iyonik iyotlu kontrast madde verilmiştir.  Elde olunan 3 Boyutlu BT ANJİOGRAFİ görüntülerinde; her iki vertebral arter ve baziler arter normal görünümdedir. Her iki internal karotis arterin petröz, kavernöz ve supraklinoid segmentleri normal görünümdedir. ASA, ASM ve PSArquote lar normal dolum göstermektedir. Intrakranial arterial yapılarda stenoz, ANEVRIZMAtik dilatasyon ya da vasküler malformasyon bulgusu saptanmamıştır.   Kemik yapılarda multıple sayıda sklerotik metastatik lezyon izlenmiştir. Kemik yapılarda multıple sayıda sklerotik metastatik lezyonlar izlenmiştir.  df1fs20  lang1053f0 lang1055f1 lang1053f0  ',
#  '   Kontrastsız BT limitleri dahilinde akut iskemik enfarkt ile uyumlu olabilecek lezyon izlenmemiştir.   b KRANİAL BT ANJİOGRAFİ TETKİKİb0   BT ANJİOGRAFİ tetkikinde kaynak imajlardan, vasküler yapıların özellikle ANEVRIZMA, stenoz ve malformasyon yönünden multiplanar ve volumetrik değerlendirilmesine olanak sağlayan MIP, MPR, SSD ve VR algoritmaları kullanılarak 3 boyutlu postproses BT ANJİOGRAFİ görüntüleri oluşturulmuştur.  IV yoldan 100 cc non iyonik iyotlu kontrast madde verilmiştir.  Elde olunan 3 Boyutlu BT ANJİOGRAFİ görüntülerinde; her iki vertebral arter ve baziler arter normal görünümdedir. Her iki internal karotis arterin petröz, kavernöz ve supraklinoid segmentleri normal görünümdedir. ASA,  ve PSArquote lar normal dolum göstermektedir. Intrakranial arterial yapılarda stenoz, ANEVRIZMAtik dilatasyon ya da vasküler malformasyon bulgusu saptanmamıştır.   Her iki MCA M1 segmenti normal dolum ve patensisinde izlenmiş olup her iki MCA trifürkasyon sonrası görüntüler uygunsuz olup net olarak değerlendirme yapılamamıştır. Gereklilik halinde olgunun MRG ile değerlendirilmesi ÖNERİLİR.   Tiroid bez sağ lobunda yaklaşık 2.5 cm nodül izlenmiş olup sonografik bakı ve değerlendirilmesi ÖNERİLİR.SONUç   Her iki MCA M1 segmenti normal dolum ve patensisinde izlenmiş olup her iki MCA trifürkasyon sonrası görüntüler uygunsuz olup net olarak değerlendirme yapılamamıştır. Gereklilik halinde olgunun MRG ile değerlendirilmesi ÖNERİLİR.   Tiroid bez sağ lobunda yaklaşık 2.5 cm nodül izlenmiş olup sonografik bakı ve değerlendirilmesi ÖNERİLİR. 20 ',
#  '   METALik enstrümanlar nedeni ile ARTEFAKTlı değerlendirilen tetkikte intrakranial kanama bulgusu izenmemiştir. ',
#  '   POSTOP kranial dekompresyon.  df1fs20 lang1053f0  ',
#  '   POSTOP.  df1fs20 lang1053f0  ',
#  '   Pre pontin sisterna , sol taraf sisterna ambiens ve her iki taraf tentorium serebelli yaprakları üzerinde SAK ile uyumlu hemorajik dansiteler izlenmiştir. Tentorium serebelli sol yaprağının yapışma yerinde bant şeklinde hiperdens bir kalınlaşma mevcut olup ilgili alanda SAK lehine yorumlanmıştır. Bulgular perimezensefalik SAK ile uyumlu görünümde olup hastanın beyin boyun BT ANJİOGRAFİ tetkiki ile değerlendirilmesi ÖNERİLİR.    20 ',
#  '   Sağ frontalden ilerletilip sağ lateral ventrikül anterior hornu iÇerisinde sonlanan VP ŞANT kateteri izlenmiştir. Ventriküler sistem dilate görünümde olup 3. ventrikül Çapı orta hatta en geniş yerinde 11.6 mm ölÇülmüştür. 4. ventrikül massif dilate görünümdedir. İntrakranial kanama bulgusu saptanmamıştır.  ',
#  '   Sağ parieto oksipital bölgeden ilerletilip sağ lateral ventrikül iÇinde sonlanmış VP ŞANT kateteri izlenmiştir. İntrakranial kanama izlenmedi.  ',
#  '   Sol temporal lob posteriorda embolize edilmiş AVM olduğu bilinen lezyonda gerileme bulguları. Pre kontrast kranial BT limitleri dahilinde akut iskemi alanı veya kanama saptanmamıştır.  lang1031 20 ',
#  '   Supratentorial kesitlerde kontrastsız BT limitleri dahilinde akut iskemi ile uyumlu alan ve intra kranial kanama saptanmamıştır. Posterior fossa kesitlerinde vertebral arter V4 segmentine yerleştirilmiş koil materyali nedeni ile oldukÇa ARTEFAKTlı olan tetkikte değerlendirilebildiği kadarı ile intra kranial kanama izlenmemiştir.  lang1031 dlang1055f2fs20  lang1053f0  ',
#  '   Takipte benzer subdural hemoraji ve pnömosefali alanları.   dqjf2fs22 b KRANİAL BT ANJİOGRAFİ TETKİKİb0   BT ANJİOGRAFİ tetkikinde kaynak imajlardan, vasküler yapıların özellikle ANEVRIZMA, stenoz ve malformasyon yönünden multiplanar ve volumetrik değerlendirilmesine olanak sağlayan MIP, MPR, SSD ve VR algoritmaları kullanılarak 3 boyutlu postproses BT ANJİOGRAFİ görüntüleri oluşturulmuştur. IV yoldan 100 cc non iyonik iyotlu kontrast madde verilmiştir.  Elde olunan 3 Boyutlu BT ANJİOGRAFİ görüntülerinde; her iki vertebral arter ve baziler arter normal görünümdedir. Her iki internal karotis arterin petröz, kavernöz ve supraklinoid segmentleri normal görünümdedir. ASA, ASM ve PSArquote lar normal dolum göstermektedir. Intrakranial arterial yapılarda stenoz, ANEVRIZMAtik dilatasyon ya da vasküler malformasyon bulgusu saptanmamıştır. SONUç   Travmatik vasküler zedelenme ayırt edilmemiştir.   20  ',
#  '   Takipte frontal lobdaki kontüzyonel hemoraji alanlarında bir miktar progresyon izlenmiş olup diğer bulgular stabildir. BT ANJİOGRAFİ tetkikinde kaynak imajlardan, vasküler yapıların özellikle ANEVRIZMA, stenoz ve malformasyon yönünden multiplanar ve volumetrik değerlendirilmesine olanak sağlayan MIP, MPR, SSD ve VR algoritmaları kullanılarak 3 boyutlu postproses BT ANJİOGRAFİ görüntüleri oluşturulmuştur. IV yoldan 100 cc non iyonik iyotlu kontrast madde verilmiştir.  Elde olunan 3 Boyutlu BT ANJİOGRAFİ görüntülerinde; sağ vertebral arter V4 segmentinden itibaren hipoplazik görünümde olup baziler artere kadar normal opasifikasyon göstermektedir. Her iki internal karotis arterin petröz, kavernöz ve supraklinoid segmentleri normal görünümdedir. ASA, ASM ve PSArquote lar normal dolum göstermektedir. Intrakranial arterial yapılarda stenoz, ANEVRIZMAtik dilatasyon ya da vasküler malformasyon bulgusu saptanmamıştır. Sağ vertebral arter V4 segmentinden itibaren hipoplazik görünümde olup baziler artere kadar normal opasifikasyon göstermektedir. ANEVRIZMAtik dilatasyon veya vasküler yaralanma bulgusuna rastlanmadı.  20  ',
#  '   Takipte yeni gelişen radyopatolojik bulgu izlenmedi. Sol occipital lob düzeyindeki METALik dansiteler nedeni ile bu düzeylerde tetkik SUBOPTIMAL değerlendirilmiştir.  lang1031 dlang1055f2fs20  lang1053f0  ',
#  '   Tüm ventriküler sistemde, tüm serebral sisternalarda, tüm serebral sulkuslarda SAK bulguları. Olgunun kranial BT ANJİOGRAFİ ile değerlendirilmesi ÖNERİLİR.  ',
#  '   Vertekste cilt altında posttravmatik değişiklikler ve cilt doku bütünlüğünde kayıp izlenmiştir. Oksipital bölge ekstrakranial alandaki yabancı cisimden kaynaklanan kaygın yansıma ARTEFAKTı nedeni ile değerlendirme oldukÇa SUBOPTIMAL olup değerlendirilebildiği kadarı ile intrakranial kanamaya ait bir bulgu saptanmamıştır. Ancak hastanın takibi ve kontrol BT ile değerlendirilmesi ÖNERİLİR. Servikal vertebralarda aşikat fraktür hattı seÇilmemiştir. df1fs20  lang1053f0  ',
#  '   VP ŞANTlı olgu. 3. ventrikül Çapı orta hatta 12 mm ölÇülmüştür. 09.08.2018 tarihli tetkik ile karşılaştırıldığında dilatasyon bulgusunda anlamlı bir değişiklik saptanmamıştır. İntrakranial kanama izlenmedi.  20  ',
#  '   VP ŞANTlı olgu. Ağustos 2018 tarihli kranial BT ile stabil bulgular. Akut radyopatolojik bulgu saptanmadı.  lang1031 dlang1055f2fs20  lang1053f0  ',
#  "   VP ŞANTlı olguda her iki lateral ventrikül ve 3. ventrikül slit görünümde olup hidrosefalik dilatasyon sözkonusu değildir. 'deant kateteri sağ parietalden ilerletilip sağ lateral ventrikül atriumunda sonlanım göstermektedir. Olgunun klinik ile beraber değerlendirmesi ÖNERİLİR.  df2fs20  lang1053f0  ",
#  '   Yoğun hareket ARTEFAKTına bağlı olarak değerlendirme ileri derecede kısıtlı olup izlenebildiği kadarı ile atrofi ve kronik iskemik değişiklikler lehine değerlendirilen bulgular izlenmektedir. Bunun dışında daha ileri yorum yapılamamaktadır.  lang1031 dlang1055f2fs20 lang1053f0  ',
#  "   lang1055 C ounter coup bölgede yeni gelişen hemorajik kontüzyon ve Çevresinde ödem sahaları. Sağ serebral serebral konveksitede BOS mesafesinde genişleme (efüzyon) izlenmiştir. 'd6nceki tetkikte belirtilen sol taraf vertekse yakın düzeydeki şüpheli hiperdens görünüm güncel tetkikte izlenmemiş olup ARTEFAKT lehine değerlendirilmiştir..lang1055 dfs20 lang2057f0fs18 ",
#  "   lang1055f1 f0fs22 Sağ frontal lobda ACA sulama alanında sekel hipodens, enfarkt sekeli hipodens ansefalomalezi alanı izlenmiştir.   dqj b KRANİAL BOYUN  BT ANJİOGRAFİ TETKİKİb0  BT ANJİOGRAFİ tetkikinde kaynak imajlardan, vasküler yapıların özellikle ANEVRIZMA, stenoz ve malformasyon yönünden multiplanar ve volumetrik değerlendirilmesine olanak sağlayan MIP, MPR, SSD ve VR algoritmaları kullanılarak 3 boyutlu postproses BT ANJİOGRAFİ görüntüleri oluşturulmuştur.  IV yoldan 100 cc non iyonik iyotlu kontrast madde verilmiştir.   Arkus aortada lümende anlamlı darlık oluşturmayan kalsifik plaklar izlenmiştir. Ayrıca sol ICA bifürkasyon düzeyinde lümende anlamlı darlık oluşturmayan miks tipte plaklar ve sağ ICA bifürkasyon düzeyinde anlamlı hemodinamik darlık oluşturmayan kalsifik plaklar izlenmiştir. Her iki ICA kavarnöz ve supraklinoid segmentlerinde lümende anlamlı darlık oluşturmayan kalsifik plaklar mevcuttur. Sol ACA A2 segment hipoplazik görünümde olup seyri boyunca opasifikasyon göstermektedir. Sağ ACA A2 segmentte kısa segment preoklüziv bir lüminal düzensizlik izlenmiş olup distalinde sağ ACA A2 ve A3 segmentleri normal dolum ve patensisinde izlenmiştir.SONUç   Sol ACA A2 hipoplazik seyirli olup normal dolum ve patensisindedir. Sağ ACA A2' de kısa segment preoklüziv bir seyir izlenmiştir. Distalinde opasifikasyon görülmektedir.fs20 ",
#  '   lang1055f2fs22 Işın sertleşme ARTEFAKTlarının fazlalığı nedeniyle özellikle frontal bölge incelemesi kısıtlıdır. Bu kısıtlılık altında belirgin intra kranial kanama izlenmedi. Fraktür izlenmedi. Normal sınıralrda Servikal vertebra BT.lang1031f3fs20 ',
#  "   Akut hidrosefali sebebi ile takip edilen olguya VP ŞANT kateteri uygulandığı görülmüştür. 'deant katateri sağ frontalden ilerletilip sağ lateral ventrikül anterior hornu iÇerisinde sonlanım göstermektedir.  ",
#  '   Bazal ganglionlar düzeyinde ve periventriküler beyaz cevherde yer yer perivasküler aralık  laküner enfarkt sekeli lehine değerlendirilen milimetrik hipodens odaklar izlenmiştir. Tetkike yansıyan belirgin intrakranial kanama, intrakranial kitle oluşumu, akut iskemi bulgusu izlenmemiştir.   . Sol ACA A1 segmentinde milimetrk boyutlu ANEVRIZMAtik oluşum dikkati Çekmektedir. Bulgular olgunun arşivimizde bulunan 17.05.2016 tarihli kranial BT anjio tetkiki ile benzer görünümdedir.    dfs20 lang2057f0fs18 ',
#  '   Bilateral maksiller sinüslerde mukozal kalınlaşmalar izlenmektedir. İntrakranial kanama, akut iskemi lehine değerlendirilen alan izlenmemektedir.   Anlamlı darlık oluşturmayan ateroskleroz bulguları izlenmiştir. İntrakranial vasküler yapılarda malformasyon  ANEVRIZMA ile uyumlu görünüm izlenmemektedir.  ',
#  ' Tetkik yoğun ARTEFAKTlı olup inceleme aÇısından uygun değildir. Tekrarı ÖNERİLİR.cf0lang1053f1fs20 ',
#  '    Bilateral eksternal kapsül düzeyinde sekel ansefalomalezi sahası izlenmiştir. Tetkike yansıyan belirgin intrakranial kanama, intrakranial kitle oluşumu, akut iskemi bulgusu izlenmemiştir.  dqj b KRANİAL  BOYUN BT ANJİOGRAFİ TETKİKİb0   BT ANJİOGRAFİ tetkikinde kaynak imajlardan, vasküler yapıların özellikle ANEVRIZMA, stenoz ve malformasyon yönünden multiplanar ve volumetrik değerlendirilmesine olanak sağlayan MIP, MPR, SSD ve VR algoritmaları kullanılarak 3 boyutlu postproses BT ANJİOGRAFİ görüntüleri oluşturulmuştur. IV yoldan 100 cc non iyonik iyotlu kontrast madde verilmiştir.  Arkus aorta düzeyinde duvar kalsifikasyonları izlenmiştir. Bilateral CCA seyri boyunca normal olarak değerlendirilmiştir. Bilateral ICA servikal düzeyde kıvrımlı seyir göstermektedir. SAğ ICA servikal segment düzeyinde 5 mm Çapında ölÇülen sakküler tipte ANEVRIZMAtik dilatasyon izlenmiştir.   Bilateral ICA tanımlanan sakküler ANEVRIZMAtik dilatasyon dışında normal patensi ve kalibrasyonda sahiptir. Bilateral MCA distal dalları normaldir. Bilateral ACA normal olarak değerlendirilmiştir. Olguda sağ vertebral arter dominansisi mevcut olup sol vertebral arter orifisinden itibaren hipoplaziktir. Hipoplazik görünüm V4 segmentinde proksimal segmentlere göre daha belirgindir. Baziler arter ve pontoserebellar dalları normaldir. Bilateral PSA seyri boyunca normal olarak değerlendirilmiştir. SONUçSağ ICA servikal düzeyde sakküler tipte ANEVRIZMAtik dilatasyon izlendi. Sol vertebral arter hipoplazik izlenmiştir. Tetkike yansıyan belirgin oklüzyon, anlamlı darlık bulgusu, intrakranial ANEVRIZMAtik dilatasyon izlenmemiştir.  f0fs20 ',
#  '   Olgunun 07.05.2019 tarihli BT incelemesi ile karşılaştırmalı olarak değerlendirilmiştir. Güncel tetkik hareket ARTEFAKTı nedeni ile ileri derecede kısıtlıdır. Bu nedenle parankimal değerlendirme kısıtlı olarak yapılabilmiştir. Güncel tetkik bu kısıtlılık altında gross olarak bir önceki tetkik ile benzerlik göstermektedir. Fakat kısıtlılık nedeni ile iskemi ekarte edilemez. Hastanın klinik bulguları ile beraber değerlendirilmesi eğer klinik şüphe Çok yüksekse gereklilik halinde diffüzyon MR ile değerlendirilmesi ÖNERİLİR. f0fs20 ',
#  '   Rapor iÇerisinde belirtilen arteriyel yapılarda hemodinamik anlamlı olmayan aterosklerotik değişiklikler mevcuttur. Vasküler yapılarda hemodinamik anlamlı darlık yada oklüzyon, ANEVRIZMAtik dilatasyon, vasküler malformasyon bulgusu saptanmamıştır. lang1053f1fs20  ',
#  '   Sağ bazal ganglionlar düzeyinde parankimal hematom izlendi(hipertansif kanama ).  Anlamlı darlık oluşturmayan aterosklerotik değişiklikler izlendi. ANEVRIZMA izlenmedi. Oklüzyon izlenmedi. f1fs20 lang2057f0fs18 ',
#  '   Sol MCA sulama alanında akut iskemik bulgular ve sol MCA M2 dalı distalinde oklüzyon izlenmiştir.. Hareket ARTEFAKTlı incelemede sol MCA bifürkasyonda 4 mm lik sakküler ANEVRIZMA izlenmiştir. İnceleme kısıtlıdır.   f1fs20 lang2057f0fs18 ',
#  '   dlang1055fs22 Belirgin hareket ARTEFAKTlı tetkikte değerlendirme oldukÇa SUBOPTIMALdir. Gross bir intrakranial kanama izlenmemekle birlikte bu tetkik ile intrakranial kanama ekarte edilemez. Belirgin bir fraktür hattı izlenmemiştir. Servikal vertebral elemanlarda aşikar bir fraktür hattı izlenmemiştir. f1fs20lang1053f0  ',
#  '   dlang1055fs22 Sağ frontal bölgede öncelikle ARTEFAKT lehine değerlendirilen fakat kanamanın ekarte edilemediği hiperdens alan izlenmektedir. Sağ maksiller sinüste effüzyon ile uyumlu görünüm izlenmektedir. Fraktür izlenmedi. Normal sınıralrda Servikal vertebra BT. f0fs20 ',
#  '   Her iki lateral ventrikülde oksipital boynuzda seviyelenme gösteren takipte benzer intraventriküler hemoraji mevcuttur. Supratentorial ventriküler sistemde non kominikan tipte takipte progrese hidrosefali izlenmektedir.   BT anjio görüntülerinde darlık veya ANEVRIZMA izlenmemiştir. İCA kavernöz  supraklinoid segmentte ateroskleroz mevcuttur.  ',
#  '   Her iki serebral ve serebellar hemisferler iÇerisinde multipl hemorajik lezyonlar ve etraflarında ödem paternleri izlenmiş olup ön planda hemorajik metastaz lehine değerlendirilen bulguların kontrastlı MRG ile incelenmesi ÖNERİLİR.  Sol vertebral arter hipoplezik seyirlidir ve V4 segmentinde ince kalibrasyonlu izlenmiştir.Sol anterior serebral arter A2 segment distalinde kısa segment darlık izlenmiş olup arter distaline kadar aÇıktır. Her iki posterior serebral arter anterior ve posterior dolaşımdan beslenmektedir. Vasküler yapılarda hemodinamik olarak anlamlı stenozoklüzyon , vasküler malformasyon, ANEVRIZMAtik dilatasyon saptanmamıştır.   lang1031',
#  '   Normal sınırlarda servikal BT ve 3 boyutlu BT incelemesi.Servikal fraktür ve dislokasyon izlenmedi.  lang1055f0 f2fs22 Normal sınırlarda Prekontrast Kranial BT tetkiki.ARTEFAKT nedeniyle SUBOPTIMAL değerlendirilmiş olup belirgin intra kranial kanama orta hat şifti izlenmemiştir. Fraktür izlenmemiştir. f0fs20 ',
#  '   Normal sınırlarda tüm spinal BT ve 3 boyutlu BT incelemesi.  lang1031 lang1055b PREKONTRAST KRANİAL BT İNCELEMESİb0  ARTEFAKT nedeni ile parankim değerlendirilmesi SUBOPTIMALdir.  Tüm kraniumu kapsayan aksiyel kesitler elde olunmuştur. Posterior fossa kesitlerinde serebellar hemisferler ve beyin sapı normaldir. 4. ventrikül normal lokalizasyon ve konfigürasyondadır. Bazal sisternalar normal genişliktedir. Posterior fossada yer kaplayan oluşum saptanmamıştır.  Supratentoryal kesitlerin değerlendirilmesinde intraserebral hipo veya hiperdens sınırlanabilen patolojik değişiklik mevcut değildir. 3. ventrikül orta hatta ve normal genişliktedir. Serebral orta hat yapılarında yer değiştirme saptanmamıştır. Serebral sulkuslar normal genişliktedir. Kafa kaidesi ve kalvarial kemik yapılar normal sınırlardadır. SONUç  Normal sınırlarda Prekontrast Kranial BT tetkiki. 20 ',
#  '   Paranazal sinüslerde mukozal kalınlaşmalar izlenimiştir. BT sınırlarında intrakranial kanama, akut iskemi, intrakranial kitle oluşumu izlenmemiştir.   Sağ İCA supraklinoid düzeyde 2 mm Çapında sakküler ANEVRIZMAtik dilatasyon izlenmiştir. Belirgin oklüzyon izlenmemiştir. Belirgin intrakranial kanama izlenmemiştir. Guatr ile uyumlu bulgular izlenmiştir. Propitozis izlenmiştir.   ',
#  '   Pre kontrast imajlarda akut iskemi lehine bir bulgu tanımlanmamıştır. Klinik bulgular eşliğinde değerlendirme gereklidir. Sol İCA terminal kesimde parsiyel tromboze sakküler ANEVRIZMA ve sol MCA M3 dallarından birinde parsiyel dolum DEFEKTi izlenmiştir. cf0lang1053f1fs20 ',
#  '   Sağ frontal lob düzeyinde hemorajik kitle izlendi. Sola doğru 5 mm şift izlendi. İntraventriküler hemoraji izlendi. Sol oksipital lob düzeyinde hipodens odak izlenmiştir. Tanımlanan lezyonların karakterize edilmesi iÇin olgunun kontrastlı kranial MRG ile değerlendirilmesi ÖNERİLİR.   Minimal aterosklerotik değişiklikler izlendi. ANEVRIZMAtik dilatasyon, oklüzyon, anlamlı darlık, aktif ekstravazasyon izlenmedi. Tiroid nodülü izlendi.  ',
#  '   Sağ konveksitede farklı evrede kanama ürünleri iÇerebilecek subdural hematom kuşkulu görünüm mevcuttur. Orta hat şifti izlenmedi. Sağ tarafta sulkuslar sola göre silik görünümdedir. Olgunun travma hikayesi ile beraber değerlendirilmesi ÖNERİLİR. Sağ frontal bölgede skalp düzeyinde hematom ile uyumlu görünüm mevcuttur. Olgunun travma hikayesi ile beraber değerlendirilmesi ÖNERİLİR.   Sağ ACA A1 segmentinde hipoplazik görünüm mevcuttur. Anlamlı darlığa neden olmayan aterosklerotik değişiklikler mevcuttur. ANEVRIZMAtik dilatasyon, vasküler malformasyon ile uyumlu görünüm izlenmedi. Boyun sağ kısmında 6 cm boyuta ulaşan tiroid nodülüne ait olduğu düşünülen görünüm mevcuttur. Olgunun elektif şartlarda USG ile değerlendirilmesi ÖNERİLİR.  ',
#  '   Sağ MCA M1 segmentine uyan bölgde dens görünüm mevcut olup akut iskemi aÇısından anlamlıdır. İntrakranial kanama izlenmedi.   b Boyun BT ve Kranial BT ANJİOGRAFİ tetkikindeb0   IV kontrast madde enjeksiyonundan sonra (100 cc iyotlu kontrast madde) aksiyel planda kaynak görüntüler elde olunmuştur. Kaynak imajlardan, vasküler yapıların özellikle ANEVRIZMA, stenoz ve malformasyon yönünden multiplanar ve volumetrik değerlendirilmesine olanak sağlayan MIP, MPR, SSD ve VR algoritmaları kullanılarak 3 boyutlu postproses BT ANJİOGRAFİ görüntüleri oluşturulmuştur.  Elde olunan 3 Boyutlu BT ANJİOGRAFİ görüntülerinde; Arkus aorta cidarında hemodinamik anlamlı olmayan kalsifik plaklar izlenmiştir. Her iki subklavian arter pre ve post vertebral segmentlerinde kitle kesite girdiği kadarıyla olağandır. Her iki CCA olağan seyirlidir. Olguda kissing İCA varyasyonu izlenmiştir. Her iki İCA supraklinoid segmentlerde kalsifik plaklar mevcuttur. Sağ MCA M1 segment orta kesiminden itibaren total oklüde izlenmiştir. Distal dallar zayıf doluş göstermektedir. Sol MCA aÇıktır. Her iki PCA aÇık izlenmiştir. Her iki vertebral arter orifislerinde ve tüm segmentlerinde olağandır. Baziler arter normal doluş göstermektedir. Her iki PCA aÇıktır.SONUç   Sağ MCA M1 segmentinde total oklüzyon izlenmiş olup akut iskemik SVO ile uyumludur.   AKUT İSKEMİK SVO  ',
#  '   Sağ serebral hemisferde ventriküler sisteme aÇılmış ve hidrosefali bulguları oluşturmuş parankimal hematom ve Çevresinde ödem bulguları izlenmiştir. Sağdan sola doğru şift mevcuttur. Ana arteriyel yapılarda anlamlı darlık , ANEVRIZMA saptanmamıştır Ateroskleroz ile uyumlu bulgular mevcuttur. Paranazal sinüslerde sinüzit bulugları mevcuttur. Akciğer üst loblarında amfizematöz değişiklikler ve mukus tıkaÇları saptanmıştır.  df0fs20 ',
#  '   Servikal spondilozis. Servikal fraktür izlenmedi. C56 vertebralar arasında vakum fenomeni izlenmiştir.   b PREKONTRAST KRANİAL BTb0  Oral materyallerin sebep olduğu ARTEFAKT ve hareket ARTEFAKTı nedeni ile SUBOPTIMAL değerlendirilmiştir.  İnfratentorial kesitlerin değerlendirilmesinde; ARTEFAKT nedeni ile SUBOPTIMAL değerlendirilmiş olup belirgin radyopatoloji izlenmedi.   Supratentorial kesitlerin değerlendirilmesinde; ventriküler sistemde ve sulkuslarda kortikal atrofiye sekonder ılımlı dilatasyon izlenmiştir. Periventriküler beyaz madde de lökoriazis sahaları dikkati Çekmektedir. Orta hat yapılarında şift saptanmamıştır.  Her iki temporal lob anteriorda araknoid aralıklarda belirginleşme izlenmiştir. Baziler arter top noktasında belirginleşme ile uyumlu görünüm izlenmiş olup ANEVRIZMA aÇısından kuşkuludur. Supraklinoid intra dural mesafede kesitler nedeni ile net anlaşılamayan ancak bilateral ICA larda genişlemeANEVRIZMA lehine kuşkulu görünüm izlenmiştir. Sol temporal anterior polde milimetrik distrofik kalsifkasyonlar dikkati Çekmiştir. lang1033f4 sol parietal lob komu351uluu287unda 4.5 mm ekstra aksu305yel hemoraji izlendi.lang1055f3  Kalvariumu oluşturan kemik yapılar ve kaide oluşumları olağan olarak izlenmektedir.   SONUç  ARTEFAKT nedeni ile posterior fossa SUBOPTIMAL  değerlendirilmiş olup kanama ekartasyonu net yapılamamaktadır. Supratentorial kesitlerin değerlendirilmesinde intra kranial kanama ve orta hat şifti izlenmedi. Bilateral temporal lob anterior pollerinde araknoid belirginleşme, solda distrofik kalsifkasyonlar izlenmiştir. Baziler arter top noktasında ANEVRIZMA lehine olabilecek genişleme dikkati Çekmiştir. Bilateral ICA lar kesitler nedeni ile net ayırt edilememiş olup giruslarla tam ayrımı yapılamamıştır. GenişlemeANEVRIZMA lehine kuşkuludur. Fraktür izlenmedi.lang1033f4 sol parietal lob komu351uluu287unda 4.5 mm ekstraaksiyel hemoraji.lang1055f3  Hastanın klinik takibi ve BT ANJİOGRAFİ ile değerlendirilmesi ÖNERİLİR.  df1fs20   lang2057f0fs18 ',
#  '   Sol frontotemporalde rapor iÇinde tanımlanan intraparankimal hemoraji ve etrafındaki yoğun vajenik paternde ödem ayırıcı tanıda öncelikle kitle iÇinde kanamayı düşündürmüştür. Olgunun kitle natürünün karakterizasyonu iÇin kontrastlı MRG ile değerlendirilmesi ÖNERİLİR.   dqjf2fs22 b KRANİAL  BOYUN BT ANJİOGRAFİ TETKİKİb0   BT ANJİOGRAFİ tetkikinde kaynak imajlardan, vasküler yapıların özellikle ANEVRIZMA, stenoz ve malformasyon yönünden multiplanar ve volumetrik değerlendirilmesine olanak sağlayan MIP, MPR, SSD ve VR algoritmaları kullanılarak 3 boyutlu postproses BT ANJİOGRAFİ görüntüleri oluşturulmuştur. IV yoldan 100 cc non iyonik iyotlu kontrast madde verilmiştir.  Elde olunan 3 Boyutlu BT ANJİOGRAFİ görüntülerinde; her iki vertebral arter ve baziler arter normal görünümdedir. Her iki internal karotis arterin petröz, kavernöz ve supraklinoid segmentleri normal görünümdedir. ASA, ASM ve PSArquote lar normal dolum göstermektedir. Intrakranial arterial yapılarda stenoz, ANEVRIZMAtik dilatasyon ya da vasküler malformasyon bulgusu saptanmamıştır.   Sol ACA A2 segmenti ödem ve hematom basısına sekonder simetriğine göre daha ince kalibrasyonda izlenmiştir.SONUçVertebrobaziler sistem, karotis sistemine ait arterial yapılar aÇıktır. İntrakranial arterial yapılar normal seyri ve patensitelerinde izlenmiştir. Vasküler yapılarda ANEVRIZMAtik dilatasyon, vasküler malformasyon, stenoz, oklüzyon ile uyumlu bir bulgu ayırt edilmemiştir. f0fs20  lang1053f1  ',
#  "   Sol konveksitede subdural hematom ve orta hatta şift izlenmektedir.   Sağ MCA'da total oklüzyon izlendi. Ayrıca bulber segmentte hafif  orta dereceli darlık şüphesi mevcuttur. Ayrıca sağ ICA paraoftalmik segmentte 2 mm saküler ANEVRIZMA izlenmektedir. Sol vertebra V4 segmentinde aterosklerotik yüksek dereceli darlık ile uyumlu görünüm mevcuttur. Sağ MCA total oklüzyonuna bağlı gelişebilecek sağ MCA akut enfarktı BT sınırlarında henüz seÇilememektedir. Olgunun gereklilik halinde difüzyon MRG ile değerlendirilmesi ÖNERİLİR.  ",
#  '   Sol MCA M2 segment düzeyinde total oklüzyon izlendi. Sağ ACA A3 segmentinde ANEVRIZMAtik dilatasyon izlendi(mikotik ANEVRIZMA). lang1031',
#  '   Sol parietal bölgede cilt altında kalsifik 18 mm boyutunda lezyon ile uyumlu görünüm mevcuttur. Olgunun klinik aÇıdan değerlendirilmesi ÖNERİLİR. Sağ oksipital bölgede cilt altında hiperdens görünüm mevcuttur (posttravmatik). Olgunun travma hikayesi ile beraber değerlendirilmesi ÖNERİLİR. BT sınırlarında akut iskemi lehine bulgu izlenmedi. Olgunun gereklilik halinde difüzyon MRG ile tetkiki ÖNERİLİR. İntrakranial kanama saptanmadı.   Sol vertebral arter orifisinde hafif  orta dereceli darlık, sol İCA petröz segmentinde kalsifik plağa bağlı hafif dereceli darlık ile uyumlu olabilecek görünüm izlenmektedir. ANEVRIZMAtik dilatasyon, vasküler malformasyonla uyumlu görünüm izlenmedi.  ',
#  "   Sol serebral konveksitede iÇerisinde değişik evreler ve kanama dansiteleri barındıran en kalın yerinde 3.5 cm ölÇülmüş subdural hemoraji alanı izlenmiştir. Sol kaudat nükleus caput düzeyinde yaklaşık 1 cm'lik intraparankimal hematom mevcutur. Orta hat yapılarında sağa doğru yaklaşık 14 mm sift izlenmiştir ve sol lateral ventrikül bası altındadır. Sol serebral hemisfer sulkuslarında silinme mevcuttur. Anjio görüntüleri belirgin hareket ARTEFAKTı iÇerdiğinden tetkik SUBOPTIMALdir. Arterial yapılarda stenoz, vasküler malformasyon veya ANEVRIZMA bulgusu saptanmamıştır.   df0fs20 ",
#  '   Takipte POSTOP hava dansitelerinde regresyon izlenmiştir. Akut radyopatolojik bulgu saptanmamıştır.   lang1053f0  ',
#  '   Takipte tam regrese izlenen SAK bulguları. Yeni gelişen bir kanama odağı ayırt edilmemiştir.  f1  Arteriyel yapılarda ANEVRIZMAtik dilatasyon bulgusu izlenmemiştir.  f0 ',
#  '   Vasküler yapılarda ANEVRIZMAtik dilatasyon, vasküler malformasyon, hemodinamik anlamlı stenoz oklüzyon izlenmemiştir. Ana venöz sinüsler aÇıktır. Olgunun kontrastlı MRG ile değerlendirilmesi ÖNERİLİR.  df0fs20 ',
#  '   Ventriküler sistemde comunikan tipte hidrosefalik dilatasyon önceki tetkikle benzer şekilde sebat etmektedir. VP ŞANT önceki tetkikte olduğu gibi sağ pariatooksipital venden ilerletilip sol lateral ventrikül iÇerisinde sonlanım göstermektedir. Orta hat yapılarında şift intra kranial kanama bulgusu izlenmemiştir.   lang1053f1  ',
#  '   VP ŞANT kateteri benzer izlenmiştir. Akut hidrosefali bulgularında progresyon izlenmiş oluıp 3. ventrikül Çapı orta hatta yaklaşık 18 mm ölÇülmüştür. İntrakranial kanama veya orta hat yapılarında sift mevcut değildir.  lang1053f0  ',
#  "   VP ŞANTlı hasta. ANEVRIZMA nedeni ile opere olduğu bildirilen olguda ACOM ve sağ MCA M1 segment düzeyinde METALik dansiteler, sağ temporal kemikte kraniotomi DEFEKTi ve sağ temporal ve frontal loblar iÇerisinde sekel gliozis  ansefalomalezi alanları izlenmiştir. Sağ oksipital lob iÇerisinde 07.06.2016 tarihli tetkik ile benzer görünümde izlenen hipodens lezyonun yanı sıra takipte yeni gelişmiş sekel gliozis ansefalomalezi alanı mevcuttur. Ventriküler sistemde bir miktar dilate izlenmiş olup 3. ventrikül Çapı orta hatta 1.2 cm'dir. Orta hat yapılarında sift izlenmemiştir.  BT sınırlarında akut iskemi ile uyumlu bir alan, intrakranial kanama izlenmemiştir. Olgunun klinik gereklilik halinde diffüzyon MRG ile değerlendirilmesi ÖNERİLİR.   lang1053f1  ",
#  '  f1fs22 Sol oksipital kemikte inferiora doğru uzanan fakat kondilleri kat etmeyen lineer fraktür hattı izlenmiştir. Sağ serebral konveksitede en geniş yerinde 2 mm ölÇülen akut subdural hematom bulgusu izlenmiştir. Sağ frontal lob iÇerisinde en geniş yerinde boyutu yaklaşık 2 cm ölÇülen intraparankimal hemnatom ve Çevre sulkuslarda lineer sak bulguları izlenmiştir. Sf0fs20 ağ vertebral arter seyri boyunca normal dolum ve patensisinde izlenmiştir. Sol vertebral arter izlenebilen V2 segmentinden itibaren hipoplazik görünümde olup V4 segmentinde PİCA şeklinde sonlanmaktadır. PİCA sonlanımına kadar sol vertebral arter normal opasifikasyon göstermektedir. ANEVRIZMAtik dilatasyon ve oklüzyon bulgusu izlenmedi.   ',
#  '  Arteriyel yapılar aÇık olup darlık ya da oklüzyon bulgusu izlenmemiştir. MRG tetkikinde sağ MCA M2 düzeyinde kuşkulu ANEVRIZMA bildirilen olguda ilgili düzeyde ve diğer arteriyel yapılarda ANEVRIZMAtik dilatasyon ayırt edilmemiştir.  ',
#  '  Baziler arter dolikoektazik seyir göstermekte olup klinik gereklilik halinde hastanın BT ANJİOGRAFİ tetkiki ile değerlendirilmesi ÖNERİLİR. Sağ parietal konveksitede uzun aksı yaklaşık 1 cm ölÇülen kalsifiye menenjiom lehine lezyon izlenmiştir. Nazal kemikte sağa doğru aÇılanma mevcuttur. Klinik ile beraber değerlendirilmesi ÖNERİLİR.  İntrakranial kanama izlenmedi.  Servikal vertebralarda fraktür hattı seÇilmedi.  20 ',
#  '  Belirgin hareket ARTEFAKTı iÇeren tetkikte değerlendirme SUBOPTIMALdir. Sağ parietooccipital bölgede cilt altında post travmatik ödem ve hematom alanları mevcuttur. Bilateral maksiller sinüsler, sol frontal sinüs ve sol anterior ethmoid hücreler iÇerisinde mukoza duvar kalınlaşması ve mukus retansiyonları izlenmiştir. Belirgin hareket ARTEFAKTlı tetkikte intra kranial kanama veya kranium kemiklerinde bir fraktür hattı izlenmemiştir.   lang1031bfs20 b0   Servikal vertebralara yönelik ince kesit aksiyel görüntüler elde olunmuştur.  Fraktür/dislokasyon varlığının araştırılması veya konfirme edilmesi iÇin MPR, MIP ve SSD gibi 3 boyutlu BT algoritmaları ile tüm planlarda 3 boyutlu postproses görüntüler oluşturulmuştur.  Tüm servikal vertebra korpus yükseklik ve disk aralıkları normaldir.   Kaynak görüntüler ya da 3 boyutlu BT görüntülerinde fraktür ya da dislokasyon izlenmedi. Spinal kanal Çapı olağandır.   Paravertebral yumuşak dokular normaldir.SONUç   Normal sınırlarda servikal BT ve 3 boyutlu BT incelemesi. Servikal vertebralarda fraktür hattı saptanmamıştır.  fs22 dlang1055f2fs20 lang1053f0  ',
#  '  Belirgin hareket ARTEFAKTlı tetkik intra kranial kanama dışlanması aÇısından SUBOPTIMALdir. Klinik değerlendirme sonrasında gerekli görülürse kontrol BT ÖNERİLİR. Kranioservikal akut fraktür izlenmedi.lang1053f0 ',
#  '  Belirgin hareket ARTEFAKTlı tetkikte değerlendirme SUBOPTIMALdir. Sol serebellar hemisferde ARTEFAKTlı tetkikte değerlendirilebildiği kadarı ile 4. ventrikülde hafif sağa doğru sifte neden olmuş hipodens görünümlü alan izlenmiştir. İskemi veya kitle ve ödemi ile ilişkili olabilir. Klinik gereklilik hastanın ileri tetkiki değerlendirilmesi ÖNERİLİR.  df1fs20',
#  '  Bu aşamada  intrakranial hemorajik ARTEFAKT oluşturan METALik materyal izlenmiştir.',
#  '  Güncel tetkik olgunun arşivimizde bulunan 23.12.2018 tarihli pre kontrast kranial BT tetkiki ile karşılaştırmalı olarak değerlendirildiğinde takipte yeni gelişen radyopatolojik bulgu izlenmemiş olup önceki raporda belirtilen perimezensefalik sisternadaki ve 4. ventrikül iÇerisindeki kanama bulguları benzer şekil ve görünümde devam etmektedir. Yeni gelişen akut radyopatolojik bulgu izlenmedi.  b KRANİAL BT ANJİOGRAFİ TETKİKİb0  BT ANJİOGRAFİ tetkikinde kaynak imajlardan, vasküler yapıların özellikle ANEVRIZMA, stenoz ve malformasyon yönünden multiplanar ve volumetrik değerlendirilmesine olanak sağlayan MIP, MPR, SSD ve VR algoritmaları kullanılarak 3 boyutlu postproses BT ANJİOGRAFİ görüntüleri oluşturulmuştur. IV yoldan 100 cc non iyonik iyotlu kontrast madde verilmiştir.  Elde olunan 3 Boyutlu BT ANJİOGRAFİ görüntülerinde; her iki vertebral arter kranial kesitlerde izlenebildiği kadarı ile normal dolum ve patensisinde izlenmiştir. Baziler arterde proksimalde fenestrasyon bulgusu mevcuttur. Her iki internal karotis arterin petröz, kavernöz ve supraklinoid segmentleri normal görünümdedir. ASA, ASM ve PSArquote lar normal dolum göstermektedir. Intrakranial arterial yapılarda stenoz, ANEVRIZMAtik dilatasyon ya da vasküler malformasyon bulgusu saptanmamıştır. SONUç  Her iki vertebral arter kranial kesitlerde izlenebildiği kadarı ile normal dolum ve patensisinde izlenmiştir. Baziler arterde proksimalde fenestrasyon bulgusu mevcuttur. ANEVRIZMAtik dilatasyon veya oklüzyon bulgusu izlenmedi.   lang1031 20 ',
#  "  Hareket ARTEFAKTlı tetkikte bilateral verteks düzeyinde lineer hiperdansiteler öncelikle ARTEFAKT lehine değerlendirilmiştir. Bunun dışında BT'ye yansıyan intrakranial patoloji izlenmemiştir. Klinik kuşku halinde kontrol BT ÖNERİLİR.  ",
#  '  Her iki frontal kemik iÇerisinden ilerletilip mezensefalon düzeyinde sonlanan bilateral derin beyin stimülatörü olduğu düşünülen METALik materyaller izlenmiştir. Tetkik materyala bağlı olarak geÇdiği kesitlerde ARTEFAKTlı izlenmiştir. Akut intrakranial kanama veya akut iskemik enfarkt ile uyumlu olabilecek lezyon izlenmemiştir. df1fs20 lang1053f0 ',
#  '  METALik klips materyalleri nedeni ile ARTEFAKTlı değerlendirilen tetkikte akut iskemi, kanamaya ait bulgu saptanmamıştır.  dfs20  ',
#  '  Normal sınırlarda beyin + boyun BT ANJİOGRAFİ tetkiki. Kontrastsız BT limitleri dahilinde akut iskemik enfarkt veya akut intrakranial kanama bulgusu izlenmemiştir.  ',
#  '  Normal sınırlarda kranial BT ve kranioservikal BT ANJİOGRAFİ tetkiki.  lang1031 20 ',
#  '  Normal sınırlarda Prekontrast Kranial BT tetkiki. ACA düzeyinde 8mm boyutunda sakküler ANEVRIZMA izlendi. Ana vasküler yapılarda anlamlı darlık yada oklüzyon izlenmedi.  lang1031 dlang1055f2fs20  lang1053f0  ',
# ...
#  ' Normal sınırlarda Prekontrast Kranial BT tetkiki, kranial ve boyun BT ANJİOGRAFİ tetkiki (sağ vertebral arterde hipoplazik görünüm ve PICA sonlanımı) ',
#  ' Normal sınırlarda Prekontrast Kranial BT tetkiki. Hasta hareket ARTEFAKTları nedeni ile SUBOPTIMAL olarak değerlendirilmiştir. Bu aşamada intrakranial hemoraji bulgusu ayırt edilmedi. Klinik korelasyon ÖNERİLİR.  ',
#  ' Normal sınırlarda Prekontrast Kranial BT tetkiki. Hasta hareket ARTEFAKTları nedeni ile tetkik SUBOPTIMAL olarak değerlendirilmiştir.  ',
#  ' Normal sınırlarda Prekontrast Kranial BT tetkiki. Kemik yapılarda POSTOP değişiklikler izlenmiştir.',
#  ' Normal sınırlarda Prekontrast Kranial BT, Boyun BT ANJİOGRAFİ, kranial BT ANJİOGRAFİ tetkiki.NORMAL.',
#  ' Normal sınırlarda VP ŞANTlı hidrosefali. Olgunun klinik korelasyonu ÖNERİLİR.',
#  ' Nsol serebral hemisfer ventrikül ve infraventriküler düzeyde kronik iskemik infarkt lehine değerlendirilen ensefalamalazi alanları yanısıra frontotemporal lobta yerleşim gösteren hiperdens karakterde lezyon ve lezyon inferior komşuluğunda koil embolizasyonuna ait materyal dansitesi izlenmektedir.KRONİK İSKEMİK İNFARKT, ENSEFALAMALAZİ ALANLARI, KOİL EMBOLİZASYONDA ANEVRIZMA.',
#  ' Nüks yada rezidü ANEVRIZMA izlenmedi. Sağ ICA supraklinoid segmentte retemirabile ile uyumlu görünüm izlenmiştir. ',
#  ' Oksipital kemik sağ yarımında kraniotomi DEFEKTine ait görünüm izlenmiş olup sağ serebellar hemisfer superiorda ansefalomalezi alanı izlenmiştir. Hastanın operasyon öyküsü eşliğinde değerlendirilmesi ÖNERİLİR.POSTOP.',
#  ' Oksipital kemik sağ yarımından başlayıp sağ temporal loba ve sağ lateral ventriküle uzanım gösteren VP ŞANT kateterlerine ait görünüm izlenmektedir. Her iki lateral ve 3. ventrikül kollabedir. VP ŞANTLI OLGU. ',
#  ' Oksipital kemikta kraniektomi DEFEKTi, bu düzeyde POSTOP dural kalınlaşma , kemik yapılarda yaygın multipl litik lezyonlar izlenmiş olup görünüm multipl miyelomun kemik tutulumu için karakteriktir.',
#  ' Oldukça ARTEFAKTlı tetkikte intrakranial kanama ve fraktür izlenmemiştir. Olgunun klinik ve radyolojik takibi ÖNERİLİR. ',
#  ' Oldukça yoğun hareket ARTEFAKTına bağlı olarak değerlendirme SUBOPTIMALdir. Maksillofasial, orbital, kafa kaidesi ve kalvariumu oluşturan kemik yapılarda frontal düzeyde beyin parankimine basıya neden olan multipl bazıları deplase fraktürler, yaygın hemosinüsler ve intra kranial kanama bulguları ve pnömosefali bulguları izlenmiştir. Bu aşamada orta hat yapılarında anlamlı şift gözlenmemiştir.',
#  ' Oldukça yoğun hareket ARTEFAKTlı tetkikte izlenebildiği kadarıyla BT ye yansıyan akut intrakranial kanama ve fraktür hattı izlenmemiştir. Olgunun klinik korelasyonu ÖNERİLİR.  ',
#  ' Olgu arşivimizde bulunan bir önceki BT ANJİOGRAFİ tetkiki ile kıyaslandığında anlamlı fark saptanmamıştır. Tüm bulgular benzer özelliktedir. Yeni gelişimli hemorajik odak ve akut infrakt sahası izlenmedi. ',
#  ' Olgu arşivimizde bulunan bir önceki BT ile kıyaslandığında stabil görünümde bulgular izlenmiştr.bilateral  serebrallar hemisfer hipodens izlendi. ARTEFAKT  klinik korelasonu gerelilik halinde ileri incelemesi uıygundur.    ',
#  ' Olguda varyasyonel kavum septum pellusidum görünümü mevcuttur. İntrakranial hemoraji bulgusu ayırt edilmemiştir. Fakat tetkik oldukça ARTEFAKT içermesi nedeniyle değerlendirme SUBOPTIMALdir. Bilateral maksiller sinüsler içerisinde sinüzit ile uyumlu havalanma kayıpları izlenmektedir.',
#  ' Olgunun önceki tetkiklerinde tarif edilen SAK ile uyumlu görünümlerde güncel tetkikte tama yakın regresyon sözkonusudur. Ventriküler sistemde dilatasyon. Sağ hemikraniumda kraniektomi DEFEKTi ve ANEVRIZMA klips materyaline ait olabilecek METALik dansite.',
#  ' Olgunun VP ŞANT kateterinin lokalizasyonu ve ventriküler sistem genişlikleri arşivimizde kayıtlı 27.02.2017 tarihli kranial BT tetkiki ile benzerdir. Bunun dışında beyin parankiminde takip sürecinde gelişen anlamlı radyolojik bulgu izlenmemiştir.',
#  ' Olgunun yoğun ARTEFAKTları nedeni ile değerlendirme SUBOPTIMAL olup kontrastsız limitasyonu dahilinde akut hemaroji veya iskemi lehine değerlendirilecek akut radyopatolojik bulgu izlenmemiştir. Olgunun klinik kolerasyonu ve gereklilik halinde radyolojik takibi uygun olacaktır.',
#  ' Olguya ait klinik arşivimizde bulunan 14.02.2017 tarihli kranial BT ile karşılaştırmalı olarak değerlendirilmiş olup, güncel tetkik yoğun ARTEFAKTlar söz konusudur. Bu nedenle güncel değerlendirme SUBOPTIMALdir. Bir önceki tetkikte izlenen sol serebral hemisfer bazal ganglion düzeyindeki intraserabral hematom ile uyumlu görünüm güncel tetkikte de devam etmekte olup, anlamlı farklılık saptanmamıştır. ',
#  ' Opere hidrosefali ile uyumlu bulgular, kronik iskemik değişiklikler.POSTOP HİDROSEFALİ.',
#  ' Oral kavitede izlenen METALik cisimlerin oluşturduğu ARTEFAKTlar nedeniyle posterior fossadan geçen kesitlerin değerlendirilmesi SUBOPTIMALdir. Sol maksiller sinüste sinüzit bulguları izlenmiştir. Hastanın değerlendirilen kranial BT tetkikinde intra kranial hemoraji veya akut iskemi bulgusu ayırtedilmemiştir. ',
#  ' Orta hat yapılarında sağ serebral hemisferdeki atrofik değişikliklere sekonder yaklaşık 4 mm boyutunda pasif yer değiştirme bulgusu izlenmiştir. Bilateral sentrum semiovale lokalizasyonunda da gliozis sahaları izlenmiştir. intrakranial hemoraji bulgusu veya BT limitasyonu dahilinde yer kaplayan oluşum saptanmadı. Akut iskemik infarkt odağı izlenmemiştir. Sağ temporoparietal lob parankiminde sekel ensefalomalazi sahaları izlenmiştir. Yanı sıra tetkikte belirgin ring artefartı izlenmiştir. Değerlendirme SUBOPTIMAL kalmıştır.  ',
#  ' Ödem bulguları dikkati çekmiş olup POSTOPeratif değişikliklerde söz konusudur. BT limitasyonunda rezidü veya nüks hakkında sağlıklı yorum yapılamaz. Olgunun MRG ile değerlendirilmesi ÖNERİLİR.',
#  ' Önceki tetkik ile aynı şekilde stabil ventriküllerde slidleşme görüldü. Olgunun VP ŞANT kateteri hiperfonksiyonu açısından kliniği ile birlikte değerlendirilmesi uygundur. Yeni gelişen hemorajik odak saptanmadı. ',
#  ' Önceki tetkikle benzer POSTOPeratif değişiklikler ve psödomeningosel ile uyumlu görünüm. Psödomeningosel komşuluğunda hipodens sahalar. Nüks açısından kuşku varsa kontrastlı kranial MRG inceleme ÖNERİLİR. ',
#  ' Önceki tetkikte izlenen kuşkulu hiperdens yapının ARTEFAKTa ait olduğu anlaşılmıştır. Yeni gelişen intrakranial hemoraji izlenmemiştir. ',
#  ' Önceki tetkikte sol frontal konveksitede izlenen milimetrik hiperdens lezyon güncel tetkikte seçilmemiş olup öncelikle ARTEFAKTa ait olduğu düşünülmüştür. Sol periorbital alanda cilt altı dokuda izlenen post travmatik değişiklikler benzerdir. ',
#  ' Özellikle verteks kesiminde yaygın hareket ARTEFAKTları nedeniyle değerlendirme oldukça SUBOPTIMALdir. Diğer serebral hemisfer sahalarının değerlendirilmesinde intrakranial hemoraji ayırt edilmemiştir. Sağ kulak kepçesi komşuluğundaki cilt altı dokularda hemorajik dansiteler izlenmekte olup, travmaya sekonder değerlendirilmiştir. Kemik yapılarda bu düzeyde travmatik değişiklik ayırt edilmemiştir.TRAVMA ',
#  ' Paranazal sinüslerde mukozal kalınlaşma ve hava sıvı seviyelenmesi veren görünüm dikkat çekmiş olup olgunun klinik korelasyonu ve gereklilik halinde maksillofasial BT ile değerlendirilmesi daha uygun olacaktır. Tetkik yoğun ARTEFAKTlıdır ve buna bağlı olarak değerlendirme ileri derecede sınırlıdır. İzlenebildiği kadarı ile intra kranial hemoraji lehine değerlendirilebilecek akut radyopatolojik bulgu ayırt edilmemiştir. Olgunun klinik korelasyonu ve gereklilik halinde radyolojik takibi uygundur.',
#  " Paranazal sinüslerde mukozal kalınlaşma ve hava sıvı seviyelenmesi, havalanma kaybı izlenmiştir. Travma öyküsü bildirilen olguda maksillofasial BT ile inceleme gerekir.Oral kavitede yerleştirilen yabancı cisimlere ait METALik artifisyel etkiyel bağlı olarak değerlendirme SUBOPTIMALdir. İzlenebildiği kadarıyla kranial BT'ye yansıyan intrakranial hemoraji, kalvaryal kemiklerde akut tipik fraktür hattı ayırt edilmemiştir.Klinik korelasyon ÖNERİLİR  ",
#  ' Paranazal sinüslerde sekresyon artışı izlenmiş olup hareket ARTEFAKTı nedeniyle maksillofasial kemik yapıların değerlendirilmesi kısıtlı kalmıştır. Fraktür kuşkusu halinde maksillofasial ince kesit BT ile değerlendirme daha uygun olacaktır. İntrakranial akut hemoraji bulgusu gözlenmemiştir.  ',
#  " Parietal kemik posteriorundan sol lateral ventriküle uzanım gösteren VP ŞANT kateteri izlenmiştir. olguda varyasyonel kavum septum pellisuda mevcuttur. 3. ventrikül çapı en geniş yerinde 1 cm'dir ve normalin üst sınırındadır. Olgunun klinik arşivimizdeki 20.10.2016 tarihli tetkik ile kıyaslandığında 3. ventrikül çapında regresyon söz konusudur. İntrakranial ödem bulgusu veya hemoraji odağı ayırt edilmemiştir. VP ŞANTLI OLGU ",
#  ' Perimezensefaik SAK izlenen olguda vasküler yapılarda anlamlı darlık, ANEVRIZMAtik dilatasyon saptanmamıştır. Obstrüktif hidrosefali ile uyumlu hafif düzeyde bulgular mevcuttur. Olgunun klinik değerlendirilmesi ve takibi ÖNERİLİR.SAK.',
#  ' Perimezensefalik SAK izlenen olguda, vasküler yapılarda ANEVRIZMAtik dilatasyon veya vasküler malformasyon ayırt edilmemiştir.PERİMEZENSEFALİK SAK.',
#  ' Pineal bölge dorsal komşuluğunda lobüle konturlu hafif hiperdens yer kaplayan oluşum izlenmiş olup hastanın elektronik istek kağıdında ANEVRIZMA öyküsü olduğu bildirilmiştir. Her iki lateral ventrikül ve 3. ventrikülde hafif dilatasyon göze çarpmış olup 4. ventrikül boyutları normal olması parsial bir akuadukt basısı veya stenozu düşünülmüştür. Transependimal ödem bulgusu izlenmedi. Ayrıca intrakranial hemoraji bulgusu gözlenmedi.',
#  ' Pnömosefalik dansitelerde regresyon , septum pellisidumda sonlanan VP ŞANT kateteri.',
#  ' Pons düzeyinde hematom ve hematomun ventirküler sisteme açılması izlendi.  Vasküler yapılarda hematom içerisinde kapiller aktif ekstravasyon bulgusu izlendi. Hidrosefali bulguları izlenmedi. Sol MCA M1 segmentinde 2 mm boyutunda ANEVRIZMA lehine dolum fazlalığı izlendi.',
#  ' Pons düzeyinde ve sağ putamen lateralinde intra parankimal hematomlar ve çevrelerinde ödem izlenmiştir. Yanısıra atrofi ve yaygın kronik iskemik laküner enfarkt alanları mevcuttur. Vasküler yapılarda anlamlı darlık mevcut değildir. Ateroskleroz bulgularına bağlı kontur düzensizlikleri ve sol MCA da iki adet sakküler ANEVRIZMA saptanmıştır.HEMATOM, İSKEMİ, SAKKÜLER ANEVRIZMALAR.',
#  ' Pons ve mezensefalon düzeyinde hemoraji bulguları mevcut olup kranial BT ANJİOGRAFİde ANJİOGRAFİye yansıyan ana vasküler yapılarda anlamlı bir hemodinamik bir oklüzyon veya ANEVRIZMA formasyonu gözlenmemiştir. Minimal aterosklerotik plaklar izlenmiş olup serebral parankimde ılımlı atrofik değişiklikler mevcuttur.  ',
#  ' POSTOP değişiklikler izlenen olguda VP ŞANT kateteri sol parietal lob parankimi içerisinde sonlanmaktadır. Akut iskemik veya hemorajik odak ayırt edilmemiştir. ',
#  ' POSTOP MCA ANEVRIZMAsı olan hasta. Sağ MCA sulama alanında hipodens sekel ensefalomalazik saha izlenmiştir.',
#  " Posterior fossa ARTEFAKTlar nedeni ile SUBOPTIMAL değerlendirilmiştir. BT'ye yansıyan hemorajik odak ayırt edilmedi. Orta hat yapılarında şift saptanmadı. ",
#  " Posterior fossa kesitleri ARTEFAKTlar nedeni ile SUBOPTIMAL değerlendirildi. Supratentoriyal kesitlerde BT'ye yansıyan hemarojik odak ve kemik yapılarda tipik fraktür hattı izlenmedi. Paranazal sinüslerde sinüzit ile ilişkili mukozal duvar kalınlaşmaları izlendi.",
#  ' Posterior fossa kesitleri ARTEFAKTlar nedeniyle sınırlı incelenmiştir. Beyin sapı infarktı tanısı bildirilen olguda BT ye yansıyan infarkt sahası izlenmedi. Olgunun klinik korelasyonu gereklilik halinde MRG incelemesi uygundur.',
#  ' Posterior fossa kesitleri artefarktlar nedeniyle SUBOPTIMAL olarak değelendirilmiştir Bu aşamada akut infarkt sahası veya hemorajik odak saptanmadı. Klinik korelasyon gereklilik halinde radyolojik takip uygundur. ',
#  ' Posterior fossa kesitlerinde mega sisterna normalden geniş bu düzeye sağ occipital kemikteki burr hole DEFEKTinden yerleştirilmiş VP ŞANT kateteri izlenmektedir. 4. ventrikül normaldir. olgunun arşivimizdeki 25.03.2017 tarihli bir önceki tetkiki ile kıyaslandığında mega sisternadaki bu dilate görünüm bir önceki tetkik ile stabildir. ',
#  ' Posterior fossa kesitlerinde mega sisterna normalden geniş olup, bu düzeyde sağ occipital kemikteki burr hole DEFEKTinden uzanım gösteren VP ŞANTa ait görünüm mevcuttur. Sinüzit bulguları mevcuttur. Klinik korelasyon ÖNERİLİR. ',
#  ' Posterior fossa kesitlerinde sol vertebral arter V4 segmenti lokalizasyonuna yerleştirilmiş belirgin METALik ARTEFAKTa sebep olan klips materyali izlenmektedir. İntrakranial hemoraji odağı ayırt edilmemiştir. Akut iskemik infarkt ile uyumlu parankim değişikliği izlenmemektedir.  ',
#  " Posterior fossa sağ yarısında POSTOPeratif değişiklikler gözlenmiş olup BT limitasyonu dahilinde rezidü veya nüks hakkında sağlıklı yorum yapılamamıştır. Ventriküler sistemde anlamlı dilatasyon mevcut değildir. Orta hat yapılarında anlamlı sift gözlenmemiştir. BT' ye yansıyan akut intrakranial kanama bulgusu izlenmemiştir. ",
#  ' Posterior fossada chiari malformasyonu ile uyumlu görünüm, her iki lateral ventrikülde hidrosefalik dilatasyon ve konturlarında düzensizlik izlenmiş olup görünüm korpus kallozum agenezisi açısından anlamlı olabilir. Hastanın gereklilik halinde ileri tetkik ile değerlendirilmesi ÖNERİLİR. Sağ parietal kemikten başlayıp sağ lateral ventriküle uzanım gösteren VP ŞANT kateterine ait görünüm izlenmiştir. VP ŞANTLI OLGU. ',
#  ' Posterior fossada serebellum parankiminde 4. ventriküle giren ve ventrikülü daraltan AVM malformasyon ile uyumlu görünüm izlenmiştir. AVM nidusunda birkaç venöz ANEVRIZMA mevcut olup, venöz drenaj derin venöz sisteme drene olmaktadır. Ventriküler sistemde hidrosefali bulgusuna rastlanmamıştır. ',
#  ' Posterior fossanın değerlendirilmesi ARTEFAKT nedeni ile kısıtlıdır. Sol serebral hemisfer bazal ganglionlar düzeyinde milimetrik subakutkronik iskemik değişiklik.',
#  ' Posterior fossanın değerlendirilmesi ışınsal ARTEFAKT nedeni ile sınırlıdır. Sol serebral hemisferde intraparankimal hemarojik dansite.',
#  ' Posterior fossanın değerlendirilmesi yoğun ışınsal ARTEFAKT nedeni ile SUBOPTIMALdir. Değerlendirilebildiği kadarı ile normal sınırlarda pre kontrast kranial BT.',
#  ' POStkontrast serilerde kontrastlanma gösteren sol frontal ve temporoparyetal alanlarda yuvarlak şekilli lezyonlar izlenmiş olup kontrastlı kranial MRG ile karakterizasyon ÖNERİLİR ( metastaz  ) kemik yapılarda POSTOPeratif DEFEKTler  ve sağ frontal serebral  parankimde ensefalomalazik değişiklikler.  ',
#  ' POSTOP bulgular, Takipte progresyon gösteren hemarojik dansiteler ve iskemi ile uyumlu olabilecek yeni gelişimli hipodens alanlar.',
#  ' POSTOP bulguları ve sekel ensefalomalazi  değişiklikler izlenen olguda akut intrakranial hemoraji  veya BT ye yansoyan  belirgin iskemi veya kitlesel oluşum gözlenmemiştir.  ',
#  ' POSTOP değişiklikler dikkat çekmiştir.  Medulloblastom nedeni ile  opere  olduğu bildirilen olguda BT limitasyonunda  rezidü veya nüks hakkında sağlıklı yorum yapılamadı.  Olgunun MRG ile değerlendirilmesi ÖNERİLİR. ',
#  ' POSTOP değişiklikler Intrakranial kanamaya  ait olabilecek sınırlanabilen radyopatoloji ayırt edilmedi. ',
#  " POSTOP değişiklikler izlenen olguda; güncel tetkikte yeni gelişen intrakranial hemoraji veya BT'ye yansıyan akut bir ödem tablosu saptanmamıştır. Sinüzit izlenmiştir.",
#  ' POSTOP değişiklikler izlenmiştir. İntrakranial akut hemaroji , fraktür izlenmemiştir.',
#  ' POSTOP değişiklikler, sulkuslar arası SAK intraventriküler hemoraji bulgularında 07.02.2018  tarihli tetkike göre bir miktar regresyonla birlikte güncel tetkikte de sebaat etmektedir. ',
#  ' POSTOP değişiklikler. VP ŞANT kateteri. Takipte stabil bulgular. ',
#  ' POSTOP değişiklikler.POSTOP.',
#  ' POSTOP değişiklikler.',
#  ' POSTOP DEĞİŞİKLİKLER.',
#  ' POSTOP değişiklikler.',
#  ' POSTOP, SAK.',
#  ' POSTOP.  ',
#  ' POSTOP. POSTOP.',
#  ' POSTOP. ',
#  ' POSTOP. ',
#  ' POSTOP. VP ŞANT kateteri.  ',
#  ' POSTOP. ',
#  ' POSTOP. ',
#  ' POSTOP. ',
#  ' POSTOP. ',
#  ' POSTOP.POSTOP. ',
#  ' POSTOP.POSTOP.',
#  ...]

# %%
df['Rapor(Sonuc)'] = df_list
df['Rapor(Sonuc)'] = df['Rapor(Sonuc)'].str.replace('SERVİKAL VERTEBRA BT ve 3 BOYUTLU BT TETKİKİ','')
df['Rapor(Sonuc)'] = df['Rapor(Sonuc)'].str.replace('SPİNAL BT ve 3 BOYUTLU BT İNCELEMESİ','')
df['Rapor(Sonuc)'] = df['Rapor(Sonuc)'].str.replace('Spondilartroz servikal BT tetkiki','')
df['Rapor(Sonuc)'] = df['Rapor(Sonuc)'].str.replace(' d ','')
df['Rapor(Sonuc)'] = df['Rapor(Sonuc)'].str.replace(r'd\\qj\\b\\f1  \\b0',r'')
df['Rapor(Sonuc)'] = df['Rapor(Sonuc)'].str.replace(r'd\\qj   \\b  \\b0',r'')
df['Rapor(Sonuc)'] = df['Rapor(Sonuc)'].str.replace(r'\\b  \\b0',r'')
df['Rapor(Sonuc)'] = df['Rapor(Sonuc)'].str.replace('SPİNAL BT ve 3 BOYUTLU BT TETKİKİ \\b0','')
df['Rapor(Sonuc)'] = df['Rapor(Sonuc)'].str.replace('\\','')

# %%
mask = (df['Rapor(Sonuc)'].str.len() >= 100)

# %%
df = df.loc[mask]

# %%
df=df.drop_duplicates()

# %%
df = df.sample(frac = 1)

# %%
df.to_excel("v2_son(2).xlsx")
